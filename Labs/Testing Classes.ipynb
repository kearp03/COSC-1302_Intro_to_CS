# %%
class Person():
    def __init__(self, fName, lName, age):
        self.fName = fName
        self.lName = lName
        self.age = age
    
    def growUp(self):
        self.age += 1
    
    def nameChange(self, fName, lName):
        self.fName = fName
        self.lName = lName
    
    def __str__(self):
        return self.fName + "\n" + self.lName + "\n" + str(self.age) + " year(s) old"
    
class Parent(Person):
    pass

class Student(Person):
    def __init__(self, fName, lName, age, school, gradYear):
        super().__init__(fName, lName, age)
        self.school = school
        self.gradYear = gradYear
    
    def transfer(self, school):
        self.school = school
    
    def __str__(self):

        return super().__str__() + "\n" + self.school + "\nClass of " + str(self.gradYear)

class Major(Student):
    def __init__(self, fName, lName, age, school, gradYear, major):
        super().__init__(fName, lName, age, school, gradYear)
        self.major = major
    
    def majorChange(self, newMajor):
        self.major = newMajor
    
    def __str__(self):
        return super().__str__() + "\nMajor: " + self.major

# ******* MAIN ******* #
family = []
n = int(input("How many people are in your family? "))

for i in range(n):
    print("Family member number " + str(i+1) + ":")
    
    firstName = input("First name: ")
    lastName = input("Last name: ")
    age = int(input("Age: "))
    status = input("Are they a student? ").lower()
    
    if(status == "yes"):
        school = input("School: ")
        year = int(input("Graduation Year: "))
        status2 = input("Do they know their major? ").lower()
        
        if(status2 == "yes"):
            major = input("Major: ")
            family.append(Major(firstName, lastName, age, school, year, major))
        
        else:
            family.append(Student(firstName, lastName, age, school, year))
    else:
        family.append(Person(firstName, lastName, age))
    print()

print("Your family: ")
for i in range(len(family)):
    print()
    print(family[i])

# %%
class Person():
    def __init__(self, fName, lName, age):
        self.fName = fName
        self.lName = lName
        self.age = age
    
    def growUp(self):
        self.age += 1
    
    def nameChange(self, fName, lName):
        self.fName = fName
        self.lName = lName
    
    def __str__(self):
        return self.fName + "\n" + self.lName + "\n" + str(self.age) + " year(s) old"
    

class Student(Person):
    def __init__(self, fName, lName, age, school, gradYear):
        super().__init__(fName, lName, age)
        self.school = school
        self.gradYear = gradYear
    
    def transfer(self, school):
        self.school = school
    
    def __str__(self):
        return super().__str__() + "\n" + self.school + "\nClass of " + str(self.gradYear)

class Major(Student):
    def __init__(self, fName, lName, age, school, gradYear, major):
        super().__init__(fName, lName, age, school, gradYear)
        self.major = major
    
    def majorChange(self, newMajor):
        self.major = newMajor
    
    def __str__(self):
        return super().__str__() + "\nMajor: " + self.major

# ******* MAIN ******* #
test = Major("First", "Last", 20, "School", 2000, "Major")
print(test)
print()
test.growUp()
print(test)
